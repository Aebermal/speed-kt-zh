# %% [markdown]
# # 3 Daten visualisieren

# %%
import requests
import json
import pandas as pd
import geopandas as gpd
import os
import fnmatch

# %%
import networkx as nx
import osmnx as ox
import numpy as np
from shapely.geometry import Point, LineString, Polygon
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

# %%
path = "Daten/out"
#patternsRosengarten = ["*Rosengarten*2*.geojson", "*Rosengarten*3*.geojson","*Rosengarten*4*.geojson","*Rosengarten*5*.geojson"]
#patternsWasserwerk = ['*Wasserwerk*2*.geojson', '*Wasserwerk*3*.geojson', '*Wasserwerk*4*.geojson', '*Wasserwerk*5*.geojson']
#patternsAlbisrieden = ['*Albisriederplatz*2*.geojson', '*Albisriederplatz*3*.geojson', '*Albisriederplatz*4*.geojson', '*Albisriederplatz*5*.geojson']

# %%
#def readGdfs(pattern, path):
 #   gdfs = []
  #  for file in os.listdir(path):
        #if fnmatch.fnmatch(file, pattern):
   #         gdfNew = gpd.read_file(path + "/" + file)
   #         gdfNew = gdfNew.to_crs(epsg=21781)
   #         gdfs.append(gdfNew)
   # return gdfs

# %%
#for pattern in patternsRosengarten:
#    gdfsRosengarten = readGdfs(pattern, path)
#for pattern in patternsWasserwerk: 
#    gdfsWasserwerk = readGdfs(pattern, path)
#for pattern in patternsAlbisrieden: 
#    gdfsAlbisrieden = readGdfs(pattern, path)

# %%
#gdfsRosengarten[0]

# %%
gdfsRosengarten2 = []
gdfsWasserwerk2 = []
gdfsAlbisrieden2 = []

# %%
    for file in os.listdir(path):
        if fnmatch.fnmatch(file, '*Rosengarten*2*.geojson'):
            gdfNew = gpd.read_file(path + "/" + file)
            gdfNew = gdfNew.to_crs(epsg=21781)
            gdfsRosengarten2.append(gdfNew)
        elif fnmatch.fnmatch(file, '*Wasserwerk*2*.geojson'):
            gdfNew = gpd.read_file(path + "/" + file)
            gdfNew = gdfNew.to_crs(epsg=21781)
            gdfsWasserwerk2.append(gdfNew)
        elif fnmatch.fnmatch(file, '*Albisriederplatz*2*.geojson'):
            gdfNew = gpd.read_file(path + "/" + file)
            gdfNew = gdfNew.to_crs(epsg=21781)
            gdfsAlbisrieden2.append(gdfNew)

# %%
gdfsRosengarten3 = []
gdfsWasserwerk3 = []
gdfsAlbisrieden3 = []

# %%
    for file in os.listdir(path):
        if fnmatch.fnmatch(file, '*Rosengarten*3*.geojson'):
            gdfNew = gpd.read_file(path + "/" + file)
            gdfNew = gdfNew.to_crs(epsg=21781)
            gdfsRosengarten3.append(gdfNew)
        elif fnmatch.fnmatch(file, '*Wasserwerk*3*.geojson'):
            gdfNew = gpd.read_file(path + "/" + file)
            gdfNew = gdfNew.to_crs(epsg=21781)
            gdfsWasserwerk3.append(gdfNew)
        elif fnmatch.fnmatch(file, '*Albisriederplatz*3*.geojson'):
            gdfNew = gpd.read_file(path + "/" + file)
            gdfNew = gdfNew.to_crs(epsg=21781)
            gdfsAlbisrieden3.append(gdfNew)

# %% [markdown]
# ## Beispiel Rosengartenstrasse

# %%
gdf_zh = ox.geocode_to_gdf("Zürich, Switzerland")
gdf_zh = gdf_zh.to_crs(epsg=21781)

# %%
G = ox.graph_from_place("Zürich, Switzerland", network_type="drive")
gdf_nodes, gdf_edges = ox.graph_to_gdfs(G)
gdf_edges = gdf_edges.to_crs(epsg=21781)

# %%
ax = gdf_zh.plot(color="lightgrey", linewidth=0.5, edgecolor='black')
gdf_edges.plot(color='grey', ax=ax)
gdfsRosengarten2[0].plot(color='red', ax=ax)
gdfsWasserwerk2[0].plot(color='yellow', ax=ax)
gdfsAlbisrieden2[0].plot(color='orange', ax=ax)
# Out:
# <AxesSubplot: >

# %%
ax = gdf_edges.plot(color="lightgrey", linewidth=0.5, edgecolor='black')
gdfsRosengarten2[0].plot(color='red', ax=ax)
gdfsWasserwerk2[0].plot(color='yellow', ax=ax)
gdfsAlbisrieden2[0].plot(color='orange', ax=ax)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Colormap festlegen

# %%
import matplotlib.colors as mcolors

norm = mcolors.Normalize(vmin=0, vmax=80)
mapper = plt.cm.ScalarMappable(norm=norm, cmap='YlOrRd')

def mystyle(edge):
    percentage = edge["properties"]["innerhalb Toleranz-Abzug"] + edge["properties"]["min 5 km/h zu schnell"] + edge["properties"]["min 10 km/h zu schnell"]

    return {
        "color": mcolors.to_hex(mapper.to_rgba(percentage)),
        "weight": 6
    }

# %% [markdown]
# ## Nacht alle Segmente

# %%
pd.concat([gdfsRosengarten2[0], gdfsRosengarten2[1], gdfsWasserwerk2[0], gdfsWasserwerk2[1],gdfsAlbisrieden2[0], gdfsAlbisrieden2[1]]).explore(tiles="CartoDB positron", style_kwds={
    "style_function": mystyle
})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9a66bcd4b53b47d96985edc57cd9241 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9a66bcd4b53b47d96985edc57cd9241&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9a66bcd4b53b47d96985edc57cd9241 = L.map(
#                 &quot;map_e9a66bcd4b53b47d96985edc57cd9241&quot;,
#                 {
#                     center: [47.38618501017597, 8.510950008358838],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e9a66bcd4b53b47d96985edc57cd9241);
#
#
#
#
#
#             var tile_layer_7b623e7c04bb4ae207b84ea7f0bf1e4d = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e9a66bcd4b53b47d96985edc57cd9241);
#
#
#             map_e9a66bcd4b53b47d96985edc57cd9241.fitBounds(
#                 [[47.37296001018075, 8.479650008332465], [47.399410010171195, 8.542250008385212]],
#                 {}
#             );
#
#
#         function geo_json_d163804a62033373ad3a8c102bf5bad2_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;10&quot;: case &quot;16&quot;: case &quot;59&quot;: case &quot;68&quot;: case &quot;69&quot;: case &quot;115&quot;: case &quot;116&quot;: case &quot;120&quot;: case &quot;125&quot;: case &quot;147&quot;: case &quot;177&quot;: case &quot;181&quot;: case &quot;295&quot;: case &quot;365&quot;:
#                     return {&quot;color&quot;: &quot;#fd9f44&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;1&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;34&quot;: case &quot;36&quot;: case &quot;62&quot;: case &quot;70&quot;: case &quot;71&quot;: case &quot;121&quot;: case &quot;149&quot;: case &quot;183&quot;: case &quot;229&quot;: case &quot;233&quot;: case &quot;252&quot;: case &quot;253&quot;: case &quot;254&quot;: case &quot;255&quot;: case &quot;260&quot;: case &quot;362&quot;: case &quot;363&quot;: case &quot;364&quot;: case &quot;369&quot;:
#                     return {&quot;color&quot;: &quot;#fec561&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;2&quot;: case &quot;4&quot;: case &quot;7&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;173&quot;: case &quot;174&quot;: case &quot;228&quot;: case &quot;231&quot;: case &quot;257&quot;: case &quot;262&quot;: case &quot;310&quot;: case &quot;356&quot;: case &quot;360&quot;: case &quot;368&quot;: case &quot;373&quot;: case &quot;402&quot;: case &quot;403&quot;: case &quot;404&quot;: case &quot;405&quot;: case &quot;409&quot;: case &quot;410&quot;:
#                     return {&quot;color&quot;: &quot;#fee38b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;3&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;72&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;112&quot;: case &quot;113&quot;: case &quot;114&quot;: case &quot;151&quot;: case &quot;157&quot;: case &quot;158&quot;: case &quot;159&quot;: case &quot;169&quot;: case &quot;170&quot;: case &quot;171&quot;: case &quot;172&quot;: case &quot;184&quot;: case &quot;185&quot;: case &quot;227&quot;: case &quot;238&quot;: case &quot;239&quot;: case &quot;240&quot;: case &quot;241&quot;: case &quot;258&quot;: case &quot;259&quot;: case &quot;261&quot;: case &quot;302&quot;: case &quot;304&quot;: case &quot;305&quot;: case &quot;306&quot;: case &quot;315&quot;: case &quot;316&quot;: case &quot;326&quot;: case &quot;327&quot;: case &quot;334&quot;: case &quot;335&quot;: case &quot;336&quot;: case &quot;355&quot;: case &quot;357&quot;: case &quot;358&quot;: case &quot;359&quot;: case &quot;361&quot;: case &quot;375&quot;: case &quot;376&quot;: case &quot;379&quot;: case &quot;380&quot;: case &quot;383&quot;: case &quot;401&quot;: case &quot;406&quot;:
#                     return {&quot;color&quot;: &quot;#ffeda0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;8&quo

# %% [markdown]
# ## Rosengartenstrasse Nacht - Tag

# %%
pd.concat(gdfsRosengarten2).explore(tiles="CartoDB positron", style_kwds={
    "style_function": mystyle
})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_090206b310cfcce1aff079003896dd0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_090206b310cfcce1aff079003896dd0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_090206b310cfcce1aff079003896dd0d = L.map(
#                 &quot;map_090206b310cfcce1aff079003896dd0d&quot;,
#                 {
#                     center: [47.388715010172376, 8.526095008372788],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_090206b310cfcce1aff079003896dd0d);
#
#
#
#
#
#             var tile_layer_5e815de7b6a796afa382920c97714293 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_090206b310cfcce1aff079003896dd0d);
#
#
#             map_090206b310cfcce1aff079003896dd0d.fitBounds(
#                 [[47.37802001017356, 8.509940008360363], [47.399410010171195, 8.542250008385212]],
#                 {}
#             );
#
#
#         function geo_json_c669a9d64216061f687b6707a85fabaa_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;10&quot;: case &quot;16&quot;: case &quot;59&quot;: case &quot;68&quot;: case &quot;69&quot;: case &quot;115&quot;: case &quot;116&quot;: case &quot;120&quot;: case &quot;125&quot;: case &quot;147&quot;: case &quot;177&quot;: case &quot;181&quot;:
#                     return {&quot;color&quot;: &quot;#fd9f44&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;1&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;34&quot;: case &quot;36&quot;: case &quot;62&quot;: case &quot;70&quot;: case &quot;71&quot;: case &quot;121&quot;: case &quot;149&quot;: case &quot;183&quot;:
#                     return {&quot;color&quot;: &quot;#fec561&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;2&quot;: case &quot;4&quot;: case &quot;7&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;173&quot;: case &quot;174&quot;:
#                     return {&quot;color&quot;: &quot;#fee38b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;3&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;72&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;112&quot;: case &quot;113&quot;: case &quot;114&quot;: case &quot;151&quot;: case &quot;157&quot;: case &quot;158&quot;: case &quot;159&quot;: case &quot;169&quot;: case &quot;170&quot;: case &quot;171&quot;: case &quot;172&quot;: case &quot;184&quot;: case &quot;185&quot;:
#                     return {&quot;color&quot;: &quot;#ffeda0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;8&quot;: case &quot;9&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;66&quot;: case &quot;67&quot;: case &quot;122&quot;: case &quot;176&quot;: case &quot;180&quot;: case &quot;182&quot;:
#                     return {&quot;color&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;11&quot;: case &quot;40&quot;: case &quot;43&quot;: case &quot;45&quot;: case &quot;46&quot;: case &quot;48&quot;: case &quot;49&quot;: case &quot;50&quot;: case &quot;51&quot;: case &quot;52&quot;: case &quot;124&quot;: case &quot;131&quot;: case &quot;132&quot;: case &quot;140&quot;: case &quot;141&quot;:
#                     return {&quot;color&quot;: &quot;#fc6c33&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;12&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;47&quot;: case &quot;53&quot;: case &quot;54&quot;: case &quot;58&quot;: case &quot;60&quot;: case &quot;61&quot;: case &quot;65&quot;: case &quot;117&quot;: case &quot;118&quot;: case &quot;119&quot;: case &quot;123&quot;: case &quot;143&quot;: case &quot;145&quot;: case &quot;146&quot;: case &quot;178&quot;: case &quot;179&quot;:
#                     return {&quot;color&quot;: &quot

# %%
pd.concat(gdfsRosengarten3).explore(tiles="CartoDB positron", style_kwds={
    "style_function": mystyle
})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ad461cbd34bef34f9f23c857eebaf89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ad461cbd34bef34f9f23c857eebaf89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ad461cbd34bef34f9f23c857eebaf89 = L.map(
#                 &quot;map_4ad461cbd34bef34f9f23c857eebaf89&quot;,
#                 {
#                     center: [47.388715010172376, 8.526095008372788],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4ad461cbd34bef34f9f23c857eebaf89);
#
#
#
#
#
#             var tile_layer_23a633bd55d5773cfd0b2b84d3984c36 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4ad461cbd34bef34f9f23c857eebaf89);
#
#
#             map_4ad461cbd34bef34f9f23c857eebaf89.fitBounds(
#                 [[47.37802001017356, 8.509940008360363], [47.399410010171195, 8.542250008385212]],
#                 {}
#             );
#
#
#         function geo_json_4e25e1de724627d86763c46fce2fb7d0_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;11&quot;: case &quot;40&quot;: case &quot;47&quot;: case &quot;53&quot;: case &quot;60&quot;: case &quot;61&quot;: case &quot;128&quot;: case &quot;129&quot;: case &quot;130&quot;: case &quot;133&quot;: case &quot;144&quot;: case &quot;145&quot;: case &quot;176&quot;: case &quot;182&quot;:
#                     return {&quot;color&quot;: &quot;#fec561&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;1&quot;: case &quot;10&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;36&quot;: case &quot;54&quot;: case &quot;58&quot;: case &quot;59&quot;: case &quot;115&quot;: case &quot;116&quot;: case &quot;117&quot;: case &quot;118&quot;: case &quot;119&quot;: case &quot;124&quot;: case &quot;126&quot;: case &quot;127&quot;: case &quot;146&quot;: case &quot;147&quot;: case &quot;183&quot;:
#                     return {&quot;color&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;2&quot;: case &quot;24&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;30&quot;: case &quot;35&quot;: case &quot;65&quot;: case &quot;66&quot;: case &quot;67&quot;: case &quot;68&quot;: case &quot;69&quot;: case &quot;121&quot;: case &quot;122&quot;: case &quot;125&quot;: case &quot;174&quot;: case &quot;184&quot;:
#                     return {&quot;color&quot;: &quot;#ffeda0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;70&quot;: case &quot;71&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;148&quot;: case &quot;149&quot;: case &quot;150&quot;: case &quot;158&quot;: case &quot;169&quot;: case &quot;170&quot;: case &quot;171&quot;: case &quot;172&quot;: case &quot;173&quot;: case &quot;185&quot;: case &quot;186&quot;: case &quot;191&quot;:
#                     return {&quot;color&quot;: &quot;#fff6b6&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;8&quot;: case &quot;9&quot;: case &quot;16&quot;: case &quot;25&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;34&quot;: case &quot;62&quot;: case &quot;120&quot;: case &quot;123&quot;: case &quot;175&quot;:
#                     return {&quot;color&quot;: &quot;#fee38b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;42&quot;: case &quot;43&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;46&quot;: case &quot;48&quot;: case &quot;49&quot;: case &quot;50&quot;: case &quot;51&quot;: case &quot;52&quot;: case &quot;57&quot;: case &quot;131&quot;: case &quot;132&quot;: case &quot;134&quot;: case &quot;135&quot;: case &quot;142&quot;: case &quot;143&quot;: case &quot;177&quot;: case &quot;179&quot;:
#                     return {&quot;color&

# %% [markdown]
# ## Wasserwerk Nacht - Tag

# %%
pd.concat(gdfsWasserwerk2).explore(tiles="CartoDB positron", style_kwds={
    "style_function": mystyle
})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2de1ecac2b955893eaf3f14d91ae563d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2de1ecac2b955893eaf3f14d91ae563d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2de1ecac2b955893eaf3f14d91ae563d = L.map(
#                 &quot;map_2de1ecac2b955893eaf3f14d91ae563d&quot;,
#                 {
#                     center: [47.387125010169896, 8.533075008380116],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2de1ecac2b955893eaf3f14d91ae563d);
#
#
#
#
#
#             var tile_layer_9ec1cec35e89818a37fd9287584b7019 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2de1ecac2b955893eaf3f14d91ae563d);
#
#
#             map_2de1ecac2b955893eaf3f14d91ae563d.fitBounds(
#                 [[47.382110010165825, 8.524580008370313], [47.39214001017396, 8.541570008389922]],
#                 {}
#             );
#
#
#         function geo_json_74d3a1fb178c8c1a488cad52e62912ed_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;52&quot;: case &quot;53&quot;: case &quot;70&quot;:
#                     return {&quot;color&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;3&quot;: case &quot;4&quot;: case &quot;33&quot;: case &quot;41&quot;: case &quot;42&quot;: case &quot;43&quot;: case &quot;44&quot;: case &quot;49&quot;: case &quot;50&quot;: case &quot;51&quot;: case &quot;54&quot;: case &quot;55&quot;: case &quot;56&quot;: case &quot;63&quot;: case &quot;71&quot;: case &quot;72&quot;:
#                     return {&quot;color&quot;: &quot;#fff6b6&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;9&quot;: case &quot;10&quot;: case &quot;14&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;76&quot;: case &quot;79&quot;: case &quot;82&quot;: case &quot;87&quot;: case &quot;91&quot;: case &quot;93&quot;: case &quot;94&quot;: case &quot;98&quot;: case &quot;101&quot;:
#                     return {&quot;color&quot;: &quot;#fc6c33&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;11&quot;: case &quot;73&quot;:
#                     return {&quot;color&quot;: &quot;#ef3323&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;15&quot;: case &quot;16&quot;: case &quot;23&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;77&quot;: case &quot;80&quot;: case &quot;81&quot;: case &quot;83&quot;: case &quot;95&quot;: case &quot;96&quot;: case &quot;100&quot;:
#                     return {&quot;color&quot;: &quot;#fd8c3c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;19&quot;: case &quot;39&quot;:
#                     return {&quot;color&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;34&quot;: case &quot;45&quot;: case &quot;46&quot;: case &quot;47&quot;: case &quot;48&quot;: case &quot;65&quot;: case &quot;66&quot;: case &quot;68&quot;:
#                     return {&quot;color&quot;: &quot;#ffeda0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;35&quot;: case &quot;38&quot;: case &quot;64&quot;: case &quot;69&quot;:
#                     return {&quot;color&quot;: &quot;#fee38b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;36&quot;: case &quot;40&quot;: case &quot;59&quot;: case &quot;60&quot;: case &quot;61&quot;: case &quot;62&quot;: case &quot;67&quot;:
#                     return {&quot;color&quot;: &quot;#fec561&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;37&quot;: case &quot;57&quot;: case &quot;58&quot;:
#                     return {&quot;color&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;102&quot;:
#                     return {&quot;colo

# %%
pd.concat(gdfsWasserwerk3).explore(tiles="CartoDB positron", style_kwds={
    "style_function": mystyle
})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_478959d4967b70cd1f93b19439b4d96a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_478959d4967b70cd1f93b19439b4d96a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_478959d4967b70cd1f93b19439b4d96a = L.map(
#                 &quot;map_478959d4967b70cd1f93b19439b4d96a&quot;,
#                 {
#                     center: [47.387125010169896, 8.533075008380116],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_478959d4967b70cd1f93b19439b4d96a);
#
#
#
#
#
#             var tile_layer_ac1f2a7e017ffd5bf85771edb0c7f8a8 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_478959d4967b70cd1f93b19439b4d96a);
#
#
#             map_478959d4967b70cd1f93b19439b4d96a.fitBounds(
#                 [[47.382110010165825, 8.524580008370313], [47.39214001017396, 8.541570008389922]],
#                 {}
#             );
#
#
#         function geo_json_e7f3d9c73cb30a21404f30a7fbdffef0_styler(feature) {
#             switch(feature.id) {
#                 case &quot;7&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;18&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;77&quot;: case &quot;81&quot;: case &quot;84&quot;: case &quot;87&quot;: case &quot;90&quot;:
#                     return {&quot;color&quot;: &quot;#fc6c33&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;8&quot;: case &quot;11&quot;: case &quot;20&quot;: case &quot;22&quot;: case &quot;78&quot;: case &quot;79&quot;: case &quot;80&quot;: case &quot;85&quot;: case &quot;89&quot;:
#                     return {&quot;color&quot;: &quot;#fc4d2a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;12&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;17&quot;: case &quot;75&quot;: case &quot;82&quot;: case &quot;86&quot;: case &quot;88&quot;: case &quot;91&quot;: case &quot;92&quot;: case &quot;97&quot;: case &quot;98&quot;: case &quot;99&quot;: case &quot;100&quot;:
#                     return {&quot;color&quot;: &quot;#fd8c3c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;16&quot;: case &quot;19&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;76&quot;: case &quot;83&quot;: case &quot;93&quot;: case &quot;96&quot;:
#                     return {&quot;color&quot;: &quot;#fd9f44&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;21&quot;:
#                     return {&quot;color&quot;: &quot;#ef3323&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;25&quot;: case &quot;94&quot;: case &quot;95&quot;: case &quot;101&quot;:
#                     return {&quot;color&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;26&quot;: case &quot;64&quot;:
#                     return {&quot;color&quot;: &quot;#fec561&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;27&quot;: case &quot;57&quot;: case &quot;59&quot;: case &quot;60&quot;: case &quot;61&quot;: case &quot;102&quot;:
#                     return {&quot;color&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;33&quot;: case &quot;35&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;40&quot;: case &quot;65&quot;: case &quot;67&quot;: case &quot;69&quot;:
#                     return {&quot;color&quot;: &quot;#ffeda0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;34&quot;: case &quot;37&quot;: case &quot;55&quot;: case &quot;56&quot;: case &quot;63&quot;: case &quot;68&quot;:
#                     return {&quot;color&quot;: &quot;#fff6b6&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;36&quot;: case &quot;58&quot;: case &quot;62&quot;:
#                     return {&quot;color&quot;: &quot;#fee38b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 default:
#                     return {&quot;color&quot;: &quot;#ffffcc&quot;, &quot;f

# %% [markdown]
# ## Albisrieden Nacht - Tag

# %%
pd.concat(gdfsAlbisrieden2).explore(tiles="CartoDB positron", style_kwds={
    "style_function": mystyle
})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a976eeda2a546b4c30af77b5eb753eba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a976eeda2a546b4c30af77b5eb753eba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a976eeda2a546b4c30af77b5eb753eba = L.map(
#                 &quot;map_a976eeda2a546b4c30af77b5eb753eba&quot;,
#                 {
#                     center: [47.37616001017953, 8.494795008346415],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_a976eeda2a546b4c30af77b5eb753eba);
#
#
#
#
#
#             var tile_layer_986150e5a8275579ddba7a62075f81c9 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a976eeda2a546b4c30af77b5eb753eba);
#
#
#             map_a976eeda2a546b4c30af77b5eb753eba.fitBounds(
#                 [[47.37296001018075, 8.479650008332465], [47.37936001017832, 8.509940008360363]],
#                 {}
#             );
#
#
#         function geo_json_aa655a3f97583636c7c04b366d2322c6_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1&quot;: case &quot;2&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;26&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;34&quot;: case &quot;35&quot;: case &quot;41&quot;: case &quot;42&quot;: case &quot;43&quot;: case &quot;78&quot;: case &quot;81&quot;: case &quot;82&quot;: case &quot;100&quot;: case &quot;101&quot;: case &quot;104&quot;: case &quot;112&quot;: case &quot;115&quot;: case &quot;117&quot;: case &quot;118&quot;: case &quot;119&quot;: case &quot;120&quot;: case &quot;122&quot;: case &quot;123&quot;: case &quot;124&quot;: case &quot;135&quot;: case &quot;137&quot;: case &quot;138&quot;: case &quot;142&quot;: case &quot;143&quot;: case &quot;144&quot;:
#                     return {&quot;color&quot;: &quot;#fff6b6&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;6&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;40&quot;: case &quot;59&quot;: case &quot;61&quot;: case &quot;62&quot;: case &quot;63&quot;: case &quot;65&quot;: case &quot;79&quot;: case &quot;80&quot;: case &quot;83&quot;: case &quot;84&quot;: case &quot;87&quot;: case &quot;105&quot;: case &quot;110&quot;:
#                     return {&quot;color&quot;: &quot;#ffeda0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;14&quot;: case &quot;60&quot;: case &quot;64&quot;: case &quot;72&quot;: case &quot;77&quot;: case &quot;106&quot;: case &quot;107&quot;: case &quot;108&quot;: case &quot;109&quot;: case &quot;113&quot;: case &quot;114&quot;:
#                     return {&quot;color&quot;: &quot;#fee38b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;36&quot;: case &quot;37&quot;: case &quot;58&quot;: case &quot;76&quot;: case &quot;85&quot;: case &quot;111&quot;: case &quot;133&quot;: case &quot;134&quot;: case &quot;139&quot;: case &quot;140&quot;: case &quot;141&quot;:
#                     return {&quot;color&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;66&quot;: case &quot;67&quot;: case &quot;68&quot;: case &quot;73&quot;:
#                     return {&quot;color&quot;: &quot;#fec561&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;69&quot;:
#                     return {&quot;color&quot;: &quot;#fd9f44&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;70&quot;:
#                     return {&quot;color&quot;: &quot;#fc6c33&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;71&quot;: case &quot;74&quot;:
#                     return {&quot;color&quot;: &quot;#e2191c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};

# %%
pd.concat(gdfsAlbisrieden3).explore(tiles="CartoDB positron", style_kwds={
    "style_function": mystyle
})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eace9c23d25dd84acd86cc0adbcf4723 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eace9c23d25dd84acd86cc0adbcf4723&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eace9c23d25dd84acd86cc0adbcf4723 = L.map(
#                 &quot;map_eace9c23d25dd84acd86cc0adbcf4723&quot;,
#                 {
#                     center: [47.37616001017953, 8.494795008346415],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_eace9c23d25dd84acd86cc0adbcf4723);
#
#
#
#
#
#             var tile_layer_976337bf04ae8025d5bf89d716b456b8 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eace9c23d25dd84acd86cc0adbcf4723);
#
#
#             map_eace9c23d25dd84acd86cc0adbcf4723.fitBounds(
#                 [[47.37296001018075, 8.479650008332465], [47.37936001017832, 8.509940008360363]],
#                 {}
#             );
#
#
#         function geo_json_cd2376e4d1de1ea6599d403003846a54_styler(feature) {
#             switch(feature.id) {
#                 case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;10&quot;: case &quot;38&quot;: case &quot;73&quot;: case &quot;79&quot;: case &quot;80&quot;: case &quot;81&quot;: case &quot;82&quot;: case &quot;83&quot;: case &quot;84&quot;: case &quot;85&quot;: case &quot;106&quot;: case &quot;107&quot;: case &quot;108&quot;: case &quot;109&quot;: case &quot;135&quot;: case &quot;139&quot;: case &quot;140&quot;:
#                     return {&quot;color&quot;: &quot;#fff6b6&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;8&quot;: case &quot;9&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;58&quot;: case &quot;60&quot;: case &quot;61&quot;: case &quot;62&quot;: case &quot;63&quot;: case &quot;64&quot;: case &quot;66&quot;: case &quot;78&quot;: case &quot;86&quot;: case &quot;111&quot;: case &quot;134&quot;:
#                     return {&quot;color&quot;: &quot;#ffeda0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;59&quot;: case &quot;65&quot;: case &quot;67&quot;: case &quot;72&quot;: case &quot;77&quot;: case &quot;133&quot;:
#                     return {&quot;color&quot;: &quot;#fee38b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;68&quot;: case &quot;69&quot;:
#                     return {&quot;color&quot;: &quot;#fec561&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;70&quot;:
#                     return {&quot;color&quot;: &quot;#fd8c3c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;71&quot;:
#                     return {&quot;color&quot;: &quot;#e2191c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;74&quot;:
#                     return {&quot;color&quot;: &quot;#ef3323&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;75&quot;:
#                     return {&quot;color&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 case &quot;76&quot;:
#                     return {&quot;color&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#                 default:
#                     return {&quot;color&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 6};
#             }
#         }
#         function geo_json_cd2376e4d1de1ea6599d403003846a54_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_cd2376e4d1de1ea6599d403003846a54_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quo
